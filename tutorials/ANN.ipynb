# %% [markdown]
# #**Artificial Neural Network (ANN)**
#
# ***Prepared by:*** [**Manisa Pipattanasomporn**](https://mpipatta.github.io)
#
# *Created: January 2, 2020 (updated: January 28, 2020)*
#
# In this tutorial, we will use ANN to perform hour-ahead load forecasting when historical load data are inputs to the forecasting model.
#
# We will use keras library.
#
#
#
#
# ---

# %% [markdown]
# #**Step 1: Load Data**
#
# Again, this notebook will work with "Bangkok.csv", the electrical consumption of a building at one-hour intervals for one year.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
np.random.seed(7)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
url ='https://raw.githubusercontent.com/mpipatta/mpipatta.github.io/master/testdata/Bangkok.csv'
df = pd.read_csv(url, index_col=[0], parse_dates=[0])[['Load','Outdoor']]
df.head(5)
#We will parse the first column (col=[0]) as the index column as the date. 
#The 'Load' column will be saved in the dataframe df.
#Note: the 'Load' is in kilo-Watt (kW).
# Out:
#                      Load  Outdoor
# Time
# 2016-01-01 00:00:00  4.30     80.5
# 2016-01-01 01:00:00  4.12     79.2
# 2016-01-01 02:00:00  4.06     79.1
# 2016-01-01 03:00:00  4.44     79.0
# 2016-01-01 04:00:00  3.88     78.8

# %%
df['Lt-1'] = df['Load'].shift(1)
df['W']=df.index.dayofweek
df['H']=df.index.hour
df.head()
# Out:
#                      Load  Outdoor  Lt-1  W  H
# Time
# 2016-01-01 00:00:00  4.30     80.5   NaN  4  0
# 2016-01-01 01:00:00  4.12     79.2  4.30  4  1
# 2016-01-01 02:00:00  4.06     79.1  4.12  4  2
# 2016-01-01 03:00:00  4.44     79.0  4.06  4  3
# 2016-01-01 04:00:00  3.88     78.8  4.44  4  4

# %%
plt.figure(figsize=(10,5))
df['Load'].plot()
df['Outdoor'].plot()

# %% [markdown]
# #**Step 2: Prepare Data**

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0,1))
data=scaler.fit_transform(df)

plt.figure(figsize=(10,5))
plt.plot(data[:,0])
plt.plot(data[:,1])

# %% [markdown]
# ### **b) Split into train vs test datasets**

# %%
# split into train and test sets
n = int(len(data)*0.8)
trainY = data[1:n,0]  #(starting from row1 to remove nan value) 
trainX = data[1:n,1:] 
testY = data[n:len(data),0]
testX = data[n:len(data),1:]

print(trainY.shape)
print(trainX.shape)
print('=====Outdoor=======Lt-1=======W=======H========Lt====')
for i in range(5):
  print(trainX[i], trainY[i])

print(testY.shape)
print(testX.shape)
print('=====Outdoor=======Lt-1=======W=======H========Lt====')
for i in range(5):
  print(testX[i,:], testY[i])
# Out:
# (7026,)
# (7026, 4)
# =====Outdoor=======Lt-1=======W=======H========Lt====
# [0.47519582 0.04069488 0.66666667 0.04347826] 0.038967271331221805
# [0.47258486 0.03896727 0.66666667 0.08695652] 0.0383914003263269
# [0.46997389 0.0383914  0.66666667 0.13043478] 0.04203858335732796
# [0.46475196 0.04203858 0.66666667 0.17391304] 0.036663787311642194
# [0.4308094  0.03666379 0.66666667 0.2173913 ] 0.053364046453594396
# (1757,)
# (1757, 4)
# =====Outdoor=======Lt-1=======W=======H========Lt====
# [0.63133159 0.14224014 0.33333333 0.82608696] 0.058162971494385256
# [0.62663185 0.05816297 0.33333333 0.86956522] 0.055859487474805646
# [0.62663185 0.05585949 0.33333333 0.91304348] 0.08215759669833955
# [0.60052219 0.0821576  0.33333333 0.95652174] 0.08167770419426049
# [0.60052219 0.0816777  0.33333333 1.        ] 0.07860639216815432

# %% [markdown]
# # **Step 3: Formulate ANN model**

# %%
from keras.optimizers import Adam
opt = Adam(lr=0.005)

model = Sequential()
model.add(Dense(6, activation='sigmoid', input_dim=4))#
model.add(Dense(6, activation='sigmoid'))#
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer=opt)
history = model.fit(trainX, trainY, validation_split=0.1, epochs=100, batch_size=24, verbose=1)
# Out:
# Train on 6323 samples, validate on 703 samples
# Epoch 1/100
# 6323/6323 [==============================] - 1s 90us/step - loss: 0.0472 - val_loss: 0.0234
# Epoch 2/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0263 - val_loss: 0.0121
# Epoch 3/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0085 - val_loss: 0.0035
# Epoch 4/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 5/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 6/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 7/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 8/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 9/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 10/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 11/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 12/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 13/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 14/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 15/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 16/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 17/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 18/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 19/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 20/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 21/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 22/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 23/100
# 6323/6323 [==============================] - 0s 54us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 24/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 25/100
# 6323/6323 [==============================] - 0s 47us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 26/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 27/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 28/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 29/100
# 6323/6323 [==============================] - 0s 47us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 30/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 31/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 32/100
# 6323/6323 [==============================] - 0s 47us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 33/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 34/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 35/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 36/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 37/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 38/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 39/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 40/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 41/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 42/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 43/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 44/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 45/100
# 6323/6323 [==============================] - 0s 47us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 46/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 47/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 48/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 49/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 50/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 51/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 52/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 53/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 54/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 55/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 56/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 57/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 58/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 59/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 60/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 61/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 62/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 63/100
# 6323/6323 [==============================] - 0s 53us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 64/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 65/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 66/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 67/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 68/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 69/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 70/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 71/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 72/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 73/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 74/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 75/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 76/100
# 6323/6323 [==============================] - 0s 53us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 77/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 78/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 79/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 80/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 81/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 82/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 83/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 84/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 85/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 86/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 87/100
# 6323/6323 [==============================] - 0s 51us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 88/100
# 6323/6323 [==============================] - 0s 56us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 89/100
# 6323/6323 [==============================] - 0s 52us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 90/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 91/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 92/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 93/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 94/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 95/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 96/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 97/100
# 6323/6323 [==============================] - 0s 50us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 98/100
# 6323/6323 [==============================] - 0s 48us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 99/100
# 6323/6323 [==============================] - 0s 47us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 100/100
# 6323/6323 [==============================] - 0s 49us/step - loss: 0.0017 - val_loss: 0.0013

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 6)                 30
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # **Step 4: Predict and calculate RMSE**

# %%
#predict the load
testPredict = model.predict(testX)

#denormalize the test set
testY_dn = testY*(df['Load'].max()-df['Load'].min())+df['Load'].min()  

#denormalize the prediction
testPredict_dn = testPredict*(df['Load'].max()-df['Load'].min())+df['Load'].min()

# %%
#plot testY vs testPredict
plt.figure(figsize=(15,8))
plt.plot(testY_dn, label='testY_dn')
plt.plot(testPredict_dn, label='testPredict_dn')
plt.legend(loc='upper left')

#calculate RMSE and MAPE
RMSE = np.sqrt(np.mean(np.square(testY_dn-testPredict_dn.ravel())))
MAPE = np.mean(np.abs((testY_dn-testPredict_dn.ravel())/testY_dn))*100

print('RMSE=',RMSE)
print('MAPE=',MAPE)
# Out:
# RMSE= 3.441446277841359
# MAPE= 25.114873107757173

# %%
plt.figure(figsize=(13,6))
plt.plot(testY_dn[600:800], label='testY_dn')
plt.plot(testPredict_dn[600:800], label='testPredict_dn')
plt.legend(loc='upper left')

# %% [markdown]
# ###**Step 5: Check model loss and validation loss**

# %%
#Check model loss and validation loss
plt.figure(figsize=(10,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
